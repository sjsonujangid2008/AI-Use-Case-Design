# %%
import pandas as pd

print("PROJECT 9 : AI USE-CASE DESIGN\n")

# Business Problem
business_problem = "Customer Churn Prediction"

# AI Approach
ai_approach = "Supervised Machine Learning (Classification)"

# Solution Details
details = {
    "Business Problem": [business_problem],
    "AI Approach": [ai_approach],
    "Input Data": ["Age, Monthly Charges, Tenure, Customer History"],
    "Expected Output": ["Predict whether customer will leave or stay"]
}

df = pd.DataFrame(details)

print("AI Solution Design")
print(df)

print("\nRisks and Ethical Concerns")
print("- Customer data should remain private.")
print("- Personal information must be protected.")
print("- AI predictions should not be biased.")
print("- Decisions should be reviewed by humans.")

print("\nConclusion")
print("AI can help businesses identify customers who may leave and improve customer retention.")

print("\nProject 9 Completed Successfully!")
# Out:
# PROJECT 9 : AI USE-CASE DESIGN
#
# AI Solution Design
#             Business Problem                                   AI Approach  \
# 0  Customer Churn Prediction  Supervised Machine Learning (Classification)
#
#                                        Input Data  \
# 0  Age, Monthly Charges, Tenure, Customer History
#
#                                Expected Output
# 0  Predict whether customer will leave or stay
#
# Risks and Ethical Concerns
# - Customer data should remain private.
# - Personal information must be protected.
# - AI predictions should not be biased.
# - Decisions should be reviewed by humans.
#
# Conclusion
# AI can help businesses identify customers who may leave and improve customer retention.
#
# Project 9 Completed Successfully!
